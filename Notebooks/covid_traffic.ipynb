# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
traffic_df = pd.read_csv('../Data/Traffic_Accidents.csv', low_memory=False)

# %%
nash_traffic_df = traffic_df[traffic_df['City'] == 'NASHVILLE']
nash_traffic_df.drop[columns = ['Collision Type Code', '']]
# Out:
#        Accident Number           Date and Time  Number of Motor Vehicles  \
# 0          20170330208  04/14/2017 10:44:00 AM                       2.0
# 1          20161069361  12/02/2016 08:09:00 PM                       2.0
# 2          20170141034  02/13/2017 12:56:00 PM                       2.0
# 5          20170402868  05/06/2017 10:05:00 AM                       2.0
# 7          20170400740  05/05/2017 04:10:00 PM                       2.0
# ...                ...                     ...                       ...
# 244624     20200331222  05/10/2020 01:55:00 PM                       2.0
# 244626     20200365200  05/24/2020 07:24:00 AM                       1.0
# 244627     20200435643  06/30/2020 01:33:00 PM                       2.0
# 244628     20200482501  07/24/2020 08:00:00 PM                       2.0
# 244629     20200329209  05/09/2020 02:35:00 PM                       2.0
#
#         Number of Injuries  Number of Fatalities Property Damage Hit and Run  \
# 0                      1.0                     0             NaN       False
# 1                      0.0                     0             NaN        True
# 2                      1.0                     0             NaN       False
# 5                      0.0                     0             NaN        True
# 7                      0.0                     0             NaN       False
# ...                    ...                   ...             ...         ...
# 244624                 1.0                     0             NaN       False
# 244626                 0.0                     0             NaN       False
# 244627                 0.0                     0             NaN       False
# 244628                 1.0                     0             NaN       False
# 244629                 1.0                     0             NaN       False
#
#        Reporting Officer  Collision Type Code  \
# 0                 716886                 11.0
# 1                 240979                  4.0
# 2                 594473                  4.0
# 5                 620067                  5.0
# 7                 140804                  5.0
# ...                  ...                  ...
# 244624            384435                  2.0
# 244626            109530                  0.0
# 244627            191578                  4.0
# 244628            409205                  5.0
# 244629            212338                 11.0
#
#                      Collision Type Description  ...  \
# 0                                 Front to Rear  ...
# 1                                         ANGLE  ...
# 2                                         ANGLE  ...
# 5                    SIDESWIPE - SAME DIRECTION  ...
# 7                    SIDESWIPE - SAME DIRECTION  ...
# ...                                         ...  ...
# 244624                                  HEAD-ON  ...
# 244626  NOT COLLISION W/MOTOR VEHICLE-TRANSPORT  ...
# 244627                                    ANGLE  ...
# 244628               SIDESWIPE - SAME DIRECTION  ...
# 244629                            Front to Rear  ...
#
#                Harmful Description                        Street Address  \
# 0       MOTOR VEHICLE IN TRANSPORT                 I24E & I24 E ENT RAMP
# 1       MOTOR VEHICLE IN TRANSPORT              HAYWOOD LN & ANTIOCH PKE
# 2       MOTOR VEHICLE IN TRANSPORT           BLACKMAN RD & TIMBERHILL DR
# 5       MOTOR VEHICLE IN TRANSPORT                 I40 W EXT RAMP & I 40
# 7       MOTOR VEHICLE IN TRANSPORT             EDGEHILL AV & HILLSIDE AV
# ...                            ...                                   ...
# 244624  MOTOR VEHICLE IN TRANSPORT          STATE HWY 155 & BROOKWOOD PL
# 244626                        TREE                       EXIT 88B & I 24
# 244627  MOTOR VEHICLE IN TRANSPORT     BLACKWOOD DR & STEWARTS FERRY PKE
# 244628  MOTOR VEHICLE IN TRANSPORT  OLD HICKORY BLVD & BRENTWOOD EAST DR
# 244629  MOTOR VEHICLE IN TRANSPORT               LEALAND LN & BATTERY LN
#
#              City State      ZIP     RPA Precinct Latitude Longitude  \
# 0       NASHVILLE    TN  37210.0  8102.0    SOUTH  36.1363  -86.7270
# 1       NASHVILLE    TN  37211.0  8851.0    SOUTH  36.0702  -86.6848
# 2       NASHVILLE    TN  37220.0  8613.0   MIDTOW  36.0747  -86.7548
# 5       NASHVILLE    TN  37203.0  4119.0   CENTRA  36.1574  -86.7900
# 7       NASHVILLE    TN  37203.0  6907.0   MIDTOW  36.1419  -86.7811
# ...           ...   ...      ...     ...      ...      ...       ...
# 244624  NASHVILLE    TN  37209.0  5107.0     WEST  36.1307  -86.8566
# 244626  NASHVILLE    TN  37207.0  2010.0   MADISO  36.2276  -86.7784
# 244627  NASHVILLE    TN  37214.0  8955.0   HERMIT  36.1526  -86.6255
# 244628  NASHVILLE    TN  37211.0  8651.0   MIDTOW  36.0452  -86.7154
# 244629  NASHVILLE    TN  37220.0  7105.0   MIDTOW  36.0883  -86.7910
#
#                  Mapped Location
# 0        POINT (-86.727 36.1363)
# 1       POINT (-86.6848 36.0702)
# 2       POINT (-86.7548 36.0747)
# 5         POINT (-86.79 36.1574)
# 7       POINT (-86.7811 36.1419)
# ...                          ...
# 244624  POINT (-86.8566 36.1307)
# 244626  POINT (-86.7784 36.2276)
# 244627  POINT (-86.6255 36.1526)
# 244628  POINT (-86.7154 36.0452)
# 244629   POINT (-86.791 36.0883)
#
# [186571 rows x 25 columns]
